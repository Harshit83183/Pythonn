# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Airline Dataset.csv")

# %%
df.head(10)
# Out:
#    Passenger ID First Name Last Name  Gender  Age            Nationality  \
# 0         10856     Edithe    Leggis  Female   62                  Japan
# 1         43872     Elwood      Catt    Male   62              Nicaragua
# 2         42633      Darby   Felgate    Male   67                 Russia
# 3         78493   Dominica      Pyle  Female   71                  China
# 4         82072        Bay   Pencost    Male   21                  China
# 5         39630       Lora   Durbann  Female   55                 Brazil
# 6         11940       Rand      Bram    Male   73            Ivory Coast
# 7         26470   Perceval  Dallosso    Male   36                Vietnam
# 8         29447      Aleda    Pigram  Female   35  Palestinian Territory
# 9         75035     Burlie   Schustl    Male   13               Thailand
#
#                         Airport Name Airport Country Code    Country Name  \
# 0                   Coldfoot Airport                   US   United States
# ...

# %%
df.tail(10)
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 98609         70741     Olimpia    Arstall  Female   22       China
# 98610         87872         Che  Pressland    Male   83      France
# 98611         37761      Hadria     Vacher  Female   41      Canada
# 98612         26208         Ody    Tineman    Male   82   Indonesia
# 98613         95651      Oneida  Ossipenko  Female   47      Serbia
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 98609  Wuzhou Changzhoudao Airport                   CN               China
# ...

# %%
df.sample(5)
# Out:
#        Passenger ID First Name   Last Name  Gender  Age Nationality  \
# 13589         36030      Randa    Westhoff  Female   17      Poland
# 58769         26040   Consuela  Strelitzki  Female   46      Russia
# 17445         89535    Cassius   Symington    Male   61     Bolivia
# 19663         58618   Nickolai      Plomer    Male   86    Slovenia
# 71020         95145      Flinn   Craigmyle    Male    3      Sweden
#
#                                       Airport Name Airport Country Code  \
# 13589    Prof. Eribelto Manoel Reino State Airport                   BR
# 58769  Gustavo Rojas Pinilla International Airport                   CO
# 17445                       Sierra Maestra Airport                   CU
# 19663                             Miyanmin Airport                   PG
# 71020                             Flamingo Airport                   CR
#
#            Country Name Airport Continent     Continents Departure Date  \
# ...

# %%
df.shape
# Out:
# (98619, 15)

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Passenger ID            int64
# First Name                str
# Last Name                 str
# Gender                    str
# Age                     int64
# Nationality               str
# Airport Name              str
# Airport Country Code      str
# Country Name              str
# Airport Continent         str
# Continents                str
# Departure Date            str
# Arrival Airport           str
# Pilot Name                str
# Flight Status             str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger ID          98619 non-null  int64
#  1   First Name            98619 non-null  str
#  2   Last Name             98619 non-null  str
#  3   Gender                98619 non-null  str
#  4   Age                   98619 non-null  int64
#  5   Nationality           98619 non-null  str
#  6   Airport Name          98619 non-null  str
#  7   Airport Country Code  98619 non-null  str
#  8   Country Name          98619 non-null  str
#  9   Airport Continent     98619 non-null  str
#  10  Continents            98619 non-null  str
#  11  Departure Date        98619 non-null  str
#  12  Arrival Airport       98619 non-null  str
#  13  Pilot Name            98619 non-null  str
#  14  Flight Status         98619 non-null  str
# dtypes: int64(2), str(13)
# memory usage: 11.3 MB

# %%
df.describe()
# Out:
#        Passenger ID           Age
# count  98619.000000  98619.000000
# mean   55168.689522     45.504021
# std    25985.443696     25.929849
# min    10000.000000      1.000000
# 25%    32608.000000     23.000000
# 50%    55338.000000     46.000000
# 75%    77695.000000     68.000000
# max    99999.000000     90.000000

# %%
df.nunique()
# Out:
# Passenger ID            59871
# First Name               8437
# Last Name               41658
# Gender                      2
# Age                        90
# Nationality               240
# Airport Name             9062
# Airport Country Code      235
# Country Name              235
# Airport Continent           6
# Continents                  6
# Departure Date            364
# Arrival Airport          9024
# Pilot Name              98610
# Flight Status               3
# dtype: int64

# %%
df[["First Name", "Last Name", "Gender", "Age"]]
# Out:
#        First Name  Last Name  Gender  Age
# 0          Edithe     Leggis  Female   62
# 1          Elwood       Catt    Male   62
# 2           Darby    Felgate    Male   67
# 3        Dominica       Pyle  Female   71
# 4             Bay    Pencost    Male   21
# ...           ...        ...     ...  ...
# 98614      Gareth    Mugford    Male   85
# 98615       Kasey   Benedict  Female   19
# 98616      Darrin     Lucken    Male   65
# 98617       Gayle  Lievesley  Female   34
# 98618  Wilhelmine     Touret  Female   10
#
# [98619 rows x 4 columns]

# %%
df[["Nationality", "Country Name", "Flight Status"]]
# Out:
#       Nationality        Country Name Flight Status
# 0           Japan       United States       On Time
# 1       Nicaragua              Canada       On Time
# 2          Russia              France       On Time
# 3           China              Canada       Delayed
# 4           China       United States       On Time
# ...           ...                 ...           ...
# 98614       China              Norway     Cancelled
# 98615      Russia          Madagascar     Cancelled
# 98616   Indonesia               Spain       On Time
# 98617       China       Côte d'Ivoire     Cancelled
# 98618      Poland  Russian Federation       Delayed
#
# [98619 rows x 3 columns]

# %%
df[["Age"]]
# Out:
#        Age
# 0       62
# 1       62
# 2       67
# 3       71
# 4       21
# ...    ...
# 98614   85
# 98615   19
# 98616   65
# 98617   34
# 98618   10
#
# [98619 rows x 1 columns]

# %%
df["Age"].mean()
# Out:
# np.float64(45.50402052342855)

# %%
df["Age"].min()
# Out:
# np.int64(1)

# %%
df["Age"].max()
# Out:
# np.int64(90)

# %%
df["Age"].median()
# Out:
# np.float64(46.0)

# %%
df["Age"].std()
# Out:
# np.float64(25.92984855207266)
