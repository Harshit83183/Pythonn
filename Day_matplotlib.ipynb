# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,20,15,30,25]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
months=['jan','Feb', 'Mar', 'Apr', 'May']
sales=[1000,150,120,180,200]
plt.plot(months, sales)
plt.title('Monthly Sales')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()

# %%
#Change Line Style
plt.plot(
    months, 
    sales,
    color="red",
    linestyle="--",
    linewidth=2,
    marker="o"
)

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May"]
sales_2025 = [100, 150, 120, 180, 220]
sales_2026 = [120, 170, 160, 200, 250]

plt.plot(months, sales_2025, marker="o")
plt.plot(months, sales_2026, marker="s")
plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
import matplotlib.pyplot as plt

students = ['Vikky', 'Rahul', 'Aman', 'Neha']
marks = [85,90,70,95]

plt.bar(students, marks, width=0.6)
plt.title("Students Marks")
plt.xlabel("students")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
#Horizontal
plt.barh(students, marks)
plt.show()

# %%
#Multiple Bar Chart
students = ["A","B","C","D"]

python = [80,70,90,60]
java = [70,75,85,80]

import numpy as np

x = np.arange(len(students))
width = 0.35

plt.bar(x - width/2 , python,width,label="Python")
plt.bar(x + width/2 , java,width,label="Java")

plt.xticks(x,students)

plt.legend()
plt.show()

# %%
# Pie Chart
import matplotlib.pyplot as plt

subjects = ["AI", "Python", "Java", "SQL"]
hours = [85, 90, 70, 95]
#explode = (0.1, 0, 0, 0)  # explode 1st slice
#mycolors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

plt.pie(hours, labels=subjects, autopct='%1.1f%%', startangle=90)


plt.title("Students Marks")
plt.show()

# %%
import matplotlib.pyplot as plt

subjects = ["AI","Python","Java","SQL"]
hours = [35,25,20,20]
explode = [0.1,0,0,0]
plt.pie(hours,
        labels=students,
        autopct='%1.1f%%',
        explode=explode,
        )
plt.show()

# %%
# Scatter Plot
import matplotlib.pyplot as plt

height = [150, 160, 170, 180, 190]
weight = [50, 60, 70, 80, 90]

plt.scatter(height, weight,
             color='blue', marker='o')

plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.title("Height vs Weight")
plt.show()

# %%
import matplotlib.pyplot as plt

marks = [55,60,65,70,75,80,85,90,95,81,97,49,30,21,10,56,70,60,89,37,50,70,46]

plt.boxplot(marks)
plt.title("Marks")
plt.show()

# %%
python = [70,75,80,85,90]
java = [60,65,70,75,80]
cpp = [65,70,75,80,85]

plt.boxplot(
    [python, java, cpp],
    labels=["Python", "Java", "C++"]
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 python = [70,75,80,85,90]
#       2 java = [60,65,70,75,80]
#       3 cpp = [65,70,75,80,85]
#       4
# ----> 5 plt.boxplot(
#       6     [python, java, cpp],
#       7     labels=["Python", "Java", "C++"]
#       8 )
#
# File ~\Desktop\Python\.venv\Lib\site-packages\matplotlib\_api\deprecation.py:477, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     471 if len(args) > name_idx:
#     472     warn_deprecated(
#     473         since, message="Passing the %(name)s %(obj_type)s "
#     474         "positionally is deprecated since Matplotlib %(since)s; the "
#     475         "parameter will become keyword-only in %(removal)s.",
#     476         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 477 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt;

# %%
data = pd.read_csv("Titanic-Dataset.csv")

# %%
avg_fare=data.groupby("Pclass")["Fare"].mean()
plt.plot(avg_fare.index,avg_fare.values,marker="o")
plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")
plt.show()

# %%
passengers = data["Pclass"].value_counts().sort_index()

print(passengers.index, passengers.values)
# Out:
# Index([1, 2, 3], dtype='int64', name='Pclass') [216 184 491]

# %%
passenger = data["Pclass"].value_counts().sort_index()

plt.bar(passengers.index, passengers.values)

plt.title("Passengers by Class")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passenger")

plt.show()

# %%
plt.hist(data["Age"].dropna(), bins=20)
plt.title("Age Distribution of Passengers")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()

# %%
plt.scatter(data["Age"], data["Fare"])

plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(
            data["Age"],
            data["Fare"],
            c=data["Pclass"]*50,
            alpha=0.6,
            marker="o",
            edgecolors="black"
)
            
plt.title("Age vs Fare by Passenger Class")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()

# %%
age_data=[
    data[data["Pclass"]==1]["Age"].dropna(),
    data[data["Pclass"]==2]["Age"].dropna(),
    data[data["Pclass"]==3]["Age"].dropna()
]
plt.boxplot(age_data)
plt.title("Age Distribution by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Age")
plt.show()
