# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
  else:
    print("a is greater than b")
# Out:
#   Cell In[6], line 5
#     elif: a == b:
#         ^
# SyntaxError: invalid syntax
